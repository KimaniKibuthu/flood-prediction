# %% [markdown]
# # Feature Engineering
# In this notebook, the features to model are created.

# %% [markdown]
# ## Import Libraries

# %%
# Set configuration for notebook
import os

os.chdir('c:\\Users\\Spectra\\flood-prediction')
os.getcwd()
# Out:
# 'c:\\Users\\Spectra\\flood-prediction'

# %%
import pandas as pd
import numpy as np
from src.utils import load_config
from sklearn.feature_selection import RFE 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
# Load the config
config = load_config()

# %% [markdown]
# # Load the data

# %%
df = pd.read_csv(config["data"]["processed_data_path"])

# %%
df
# Out:
#           Sl Station_Names  Year  Month  Max_Temp  Min_Temp  Rainfall  \
# 0          0       Barisal  1949      1      29.4      12.3       0.0
# 1          1       Barisal  1949      2      33.9      15.2       9.0
# 2          2       Barisal  1949      3      36.7      20.2       8.0
# 3          3       Barisal  1949      4      33.9      23.9     140.0
# 4          4       Barisal  1949      5      35.6      25.0     217.0
# ...      ...           ...   ...    ...       ...       ...       ...
# 20539  20539        Teknaf  2013      8      32.5      25.4     851.0
# 20540  20540        Teknaf  2013      9      32.6      25.7     329.0
# 20541  20541        Teknaf  2013     10      33.1      24.8     271.0
# 20542  20542        Teknaf  2013     11      32.5      20.0       0.0
# 20543  20543        Teknaf  2013     12      29.9      16.5       0.0
#
#        Relative_Humidity  Wind_Speed  Cloud_Coverage  Bright_Sunshine  \
# 0                   68.0    0.453704             0.6         7.831915
# 1                   63.0    0.659259             0.9         8.314894
# 2                   59.0    1.085185             1.5         8.131915
# 3                   71.0    1.772222             3.9         8.219149
# 4                   76.0    1.703704             4.1         7.046809
# ...                  ...         ...             ...              ...
# 20539               88.0    2.500000             6.2         3.800000
# 20540               88.0    3.000000             6.1         4.200000
# 20541               85.0    2.500000             4.4         5.600000
# 20542               79.0    2.100000             1.7         8.400000
# 20543               72.0    3.000000             0.9         8.100000
#
#        Station_Number     X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period  \
# 0               41950  536809.8  510151.9     22.70      90.36    4  1949.01
# 1               41950  536809.8  510151.9     22.70      90.36    4  1949.02
# 2               41950  536809.8  510151.9     22.70      90.36    4  1949.03
# 3               41950  536809.8  510151.9     22.70      90.36    4  1949.04
# 4               41950  536809.8  510151.9     22.70      90.36    4  1949.05
# ...               ...       ...       ...       ...        ...  ...      ...
# 20539           41998  734765.4  308914.1     20.87      92.26    4  2013.08
# 20540           41998  734765.4  308914.1     20.87      92.26    4  2013.09
# 20541           41998  734765.4  308914.1     20.87      92.26    4  2013.10
# 20542           41998  734765.4  308914.1     20.87      92.26    4  2013.11
# 20543           41998  734765.4  308914.1     20.87      92.26    4  2013.12
#
#        Flood
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 20539      1
# 20540      0
# 20541      0
# 20542      0
# 20543      0
#
# [20544 rows x 19 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# **Drop highly correlated columns**

# %%
df.drop(["X_COR", "Y_COR", "Sl"], axis=1, inplace=True)

# %% [markdown]
# **Create Average Temperature**

# %%
df["Avg_Temp"] = (df["Max_Temp"] + df["Min_Temp"]) / 2

# %% [markdown]
# **Create spatial features**

# %%
from pykrige.ok import OrdinaryKriging

# Assuming df contains latitude, longitude, and rainfall columns
longitudes = df['LONGITUDE'].values
latitudes = df['LATITUDE'].values
values = df['Rainfall'].values

OK = OrdinaryKriging(longitudes, latitudes, values,
                     variogram_model='spherical',
                     verbose=False,
                     enable_plotting=False)

# Interpolate rainfall using Ordinary Kriging
df['rainfall_interpolated'], _ = OK.execute('points',longitudes, latitudes)

# %%
# Create interaction features
df['rain_latitude'] = df['Rainfall'] * df['LATITUDE']
df['rain_longitude'] = df['Rainfall'] * df['LONGITUDE']

# %% [markdown]
# **Create distance to waterbodies feature**

# %%
import geopandas as gpd


# Assuming df is your DataFrame with latitude and longitude columns
# Create GeoDataFrame from DataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.LONGITUDE, df.LATITUDE))

# Load water body GeoDataFrame from OpenStreetMap
try:
    water_bodies = gpd.read_file("data/raw/bgd_hyd_rivers_lged.shp")
except Exception as e:
    # If there's an error reading the shapefile, attempt to recreate the index file
    water_bodies = gpd.read_file("data/raw/bgd_hyd_rivers_lged.shp")
    # Create spatial index
    water_bodies.sindex

# Calculate distances to nearest water body
gdf['dist_to_water'] = gdf.geometry.apply(lambda x: water_bodies.distance(x).min())

# Assign the calculated distances back to the original DataFrame
df['dist_to_water'] = gdf['dist_to_water']
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 18
#      15     water_bodies.sindex
#      17 # Calculate distances to nearest water body
# ---> 18 gdf['dist_to_water'] = gdf.geometry.apply(lambda x: water_bodies.distance(x).min())
#      20 # Assign the calculated distances back to the original DataFrame
#      21 df['dist_to_water'] = gdf['dist_to_water']
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\geoseries.py:680, in GeoSeries.apply(self, func, convert_dtype, args, **kwargs)
#     677         kwargs["convert_dtype"] = True
#     679 # to avoid warning
# --> 680 result = super().apply(func, args=args, **kwargs)
#     681 if isinstance(result, GeoSeries):
#     682     if self.crs is not None:
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\base.py:919, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     916 arr = self._values
#     918 if isinstance(arr, ExtensionArray):
# --> 919     return arr.map(mapper, na_action=na_action)
#     921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\arrays\base.py:2322, in ExtensionArray.map(self, mapper, na_action)
#    2302 def map(self, mapper, na_action=None):
#    2303     """
#    2304     Map values using an input mapping or function.
#    2305
#    (...)
#    2320         a MultiIndex will be returned.
#    2321     """
# -> 2322     return map_array(self, mapper, na_action=na_action)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[18], line 18, in <lambda>(x)
#      15     water_bodies.sindex
#      17 # Calculate distances to nearest water body
# ---> 18 gdf['dist_to_water'] = gdf.geometry.apply(lambda x: water_bodies.distance(x).min())
#      20 # Assign the calculated distances back to the original DataFrame
#      21 df['dist_to_water'] = gdf['dist_to_water']
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\base.py:2577, in GeoPandasBase.distance(self, other, align)
#    2483 def distance(self, other, align=True):
#    2484     """Returns a ``Series`` containing the distance to aligned `other`.
#    2485
#    2486     The operation works on a 1-to-1 row-wise manner:
#    (...)
#    2575     dtype: float64
#    2576     """
# -> 2577     return _binary_op("distance", self, other, align)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\base.py:63, in _binary_op(op, this, other, align, *args, **kwargs)
#      60 def _binary_op(op, this, other, align, *args, **kwargs):
#      61     # type: (str, GeoSeries, GeoSeries, args/kwargs) -> Series[bool/float]
#      62     """Binary operation on GeoSeries objects that returns a Series"""
# ---> 63     data, index = _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      64     return Series(data, index=index)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\base.py:47, in _delegate_binary_method(op, this, other, align, *args, **kwargs)
#      44 else:
#      45     raise TypeError(type(this), type(other))
# ---> 47 data = getattr(a_this, op)(other, *args, **kwargs)
#      48 return data, this.index
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\array.py:693, in GeometryArray.distance(self, other)
#     691 def distance(self, other):
#     692     self.check_geographic_crs(stacklevel=6)
# --> 693     return self._binary_method("distance", self, other)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\array.py:611, in GeometryArray._binary_method(op, left, right, **kwargs)
#     608         _crs_mismatch_warn(left, right, stacklevel=7)
#     609     right = right._data
# --> 611 return getattr(vectorized, op)(left._data, right, **kwargs)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\geopandas\_vectorized.py:982, in distance(data, other)
#     980 def distance(data, other):
#     981     if compat.USE_SHAPELY_20:
# --> 982         return shapely.distance(data, other)
#     983     elif compat.USE_PYGEOS:
#     984         return _binary_method("distance", data, other)
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\Spectra\flood-prediction\.venv\Lib\site-packages\shapely\measurement.py:72, in distance(a, b, **kwargs)
#      47 @multithreading_enabled
#      48 def distance(a, b, **kwargs):
#      49     """Computes the Cartesian distance between two geometries.
#      50
#      51     Parameters
#    (...)
#      70     nan
#      71     """
# ---> 72     return lib.distance(a, b, **kwargs)
#
# KeyboardInterrupt:

# %%
df
# Out:
#       Station_Names  Year  Month  Max_Temp  Min_Temp  Rainfall  \
# 0           Barisal  1949      1      29.4      12.3       0.0
# 1           Barisal  1949      2      33.9      15.2       9.0
# 2           Barisal  1949      3      36.7      20.2       8.0
# 3           Barisal  1949      4      33.9      23.9     140.0
# 4           Barisal  1949      5      35.6      25.0     217.0
# ...             ...   ...    ...       ...       ...       ...
# 20539        Teknaf  2013      8      32.5      25.4     851.0
# 20540        Teknaf  2013      9      32.6      25.7     329.0
# 20541        Teknaf  2013     10      33.1      24.8     271.0
# 20542        Teknaf  2013     11      32.5      20.0       0.0
# 20543        Teknaf  2013     12      29.9      16.5       0.0
#
#        Relative_Humidity  Wind_Speed  Cloud_Coverage  Bright_Sunshine  \
# 0                   68.0    0.453704             0.6         7.831915
# 1                   63.0    0.659259             0.9         8.314894
# 2                   59.0    1.085185             1.5         8.131915
# 3                   71.0    1.772222             3.9         8.219149
# 4                   76.0    1.703704             4.1         7.046809
# ...                  ...         ...             ...              ...
# 20539               88.0    2.500000             6.2         3.800000
# 20540               88.0    3.000000             6.1         4.200000
# 20541               85.0    2.500000             4.4         5.600000
# 20542               79.0    2.100000             1.7         8.400000
# 20543               72.0    3.000000             0.9         8.100000
#
#        Station_Number  LATITUDE  LONGITUDE  ALT   Period  Flood  Avg_Temp
# 0               41950     22.70      90.36    4  1949.01      0     20.85
# 1               41950     22.70      90.36    4  1949.02      0     24.55
# 2               41950     22.70      90.36    4  1949.03      0     28.45
# 3               41950     22.70      90.36    4  1949.04      0     28.90
# 4               41950     22.70      90.36    4  1949.05      0     30.30
# ...               ...       ...        ...  ...      ...    ...       ...
# 20539           41998     20.87      92.26    4  2013.08      1     28.95
# 20540           41998     20.87      92.26    4  2013.09      0     29.15
# 20541           41998     20.87      92.26    4  2013.10      0     28.95
# 20542           41998     20.87      92.26    4  2013.11      0     26.25
# 20543           41998     20.87      92.26    4  2013.12      0     23.20
#
# [20544 rows x 17 columns]

# %% [markdown]
# **Select the best features**

# %%
# Separate features (X) and target variable (y)
X = df.drop(columns=["Flood", "Station_Names", "Period"])  # Features are all columns except "Flood"
y = df["Flood"]  # Target variable is "Flood"

# Initialize a classifier 
clf = RandomForestClassifier()

# Initialize RFE with the classifier and number of desired features
rfe = RFE(estimator=clf, n_features_to_select=4)  

# Fit RFE to your df
rfe.fit(X, y)

# Get the selected features
selected_features = X.columns[rfe.support_]

print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['Rainfall', 'Cloud_Coverage', 'Bright_Sunshine', 'Station_Number'], dtype='object')

# %%
train_features_set = ['Rainfall', 'Cloud_Coverage', 'Bright_Sunshine','Station_Number', "Flood"]
train_features_set_one =  ['Rainfall', 'Max_Temp', 'Min_Temp', 'Relative_Humidity', 'Wind_Speed', 'Month', 'Flood']

# %% [markdown]
# We can now train the model using the set of features obtained

# %% [markdown]
# ## Split the data

# %%
# Split the data
modelling_data = df[train_features_set_one]

train, test = train_test_split(modelling_data,
                               test_size=0.2,
                               random_state=42,
                               stratify=modelling_data["Flood"])

# %%
# Save the data
train.to_csv(config["data"]["train_data_path"], index=False)
test.to_csv(config["data"]["test_data_path"], index=False)
